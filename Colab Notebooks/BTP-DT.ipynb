# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Input, Dropout, Flatten
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import math
import os
import random
from joblib import dump, load
import gzip
import msgpack
import sys
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.utils import resample
from imblearn.over_sampling import SMOTE
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt
import msgpack
import gzip
import io
import numpy as np
import joblib
import zlib

# %%
df = pd.DataFrame()
for i in range(1, 11):
    df1 = pd.DataFrame()
    df1 = pd.read_csv(f'/content/drive/MyDrive/BTP-DataSets/MHEALTHDATASET/mHealth_subject{i}.log', header=None, sep='\t')
    df1 = df1.rename(columns={0: "acx", 1: "acy", 2: "acz", 3: "es1", 4: "es2",
                              5: "alx", 6: "aly", 7: "alz", 8: "glx", 9: "gly", 10: "glz", 11: "mlx", 12: "mly",
                              13: "mlz", 14: "arx", 15: "ary", 16: "arz", 17: "grx", 18: "gry", 19: "grz", 20: "mrx",
                              21: "mry", 22: "mrz", 23: "Activity"})
    df = pd.concat([df, df1])

# %%
pd.value_counts(df['Activity']).plot.bar()
# Out:
# <Axes: >

# %%
from sklearn.utils import resample

df_majority = df[df.Activity==0]
df_minorities = df[df.Activity!=0]

df_majority_downsampled = resample(df_majority,n_samples=30000, random_state=50)
df = pd.concat([df_majority_downsampled, df_minorities])
df.Activity.value_counts()
# Out:
# 1     30720
# 2     30720
# 3     30720
# 4     30720
# 9     30720
# 10    30720
# 11    30720
# 5     30720
# 0     30000
# 7     29441
# 8     29337
# 6     28315
# 12    10342
# Name: Activity, dtype: int64

# %%
num_of_clusters = 5
clusters_df=[]
for _ in range(num_of_clusters):
    clusters_df.append(df.sample(100000, replace=False))
cluster_heads=np.array([-1,-1,-1,-1,-1])

# %%
workers_info = []
energy_for_edge_at_start = 100000

# data, cluster no, edge score, model - coeff, model - intercept, energy consumed, acc
for i in range(5):
    for j in range(5):
        worker_data = pd.DataFrame(clusters_df[i].sample(30000, replace=False))
        worker_id = i
        worker_score = 0
        worker_coef = 0
        worker_intercept = 0
        worker_energy = []
        energy_acc = []
        energy = energy_for_edge_at_start
        workers_info.append([worker_data, worker_id, worker_coef, worker_score,
                             worker_intercept, worker_energy, energy_acc, energy])

# %%
fig = plt.figure(figsize=(18, 10))
for i, worker in enumerate(workers_info):
    ax = fig.add_subplot(5, 5, i + 1)
    pd.value_counts(worker[0]['Activity']).plot.bar(ax=ax)
    ax.set_title(f'Worker {i + 1}')
fig.tight_layout()
plt.show()

# %%
import msgpack
import gzip
import io
import numpy as np
import joblib
import zlib

def extract(message):
    if message is None:
        return None, None

    try:
        # Use joblib.load to handle non-compressed models
        model = joblib.load(io.BytesIO(message))
        return model, None
    except Exception:
        pass

    try:
        # Handle gzipped models
        decompressed_byte_array = zlib.decompress(message)
        model = joblib.load(io.BytesIO(decompressed_byte_array))
        return model, None
    except Exception:
        pass

    # Return default values if extraction fails
    return None, None


def compress(model):
    try:
        # Save the model to a BytesIO object using joblib.dump
        model_bytesio = io.BytesIO()
        joblib.dump(model, model_bytesio)

        # Get the serialized model bytes
        model_bytes = model_bytesio.getvalue()

        # Compress the serialized model using gzip
        compressed_model = gzip.compress(model_bytes)

        # Store the compressed model in a MessagePack container
        message_pack_container = msgpack.packb([compressed_model])
        return message_pack_container
    except Exception:
        return None

# %%
max_rounds = 100  # Maximum number of training rounds
req_accuracy = 0.80  # Minimum accuracy threshold
negligible_change = 0.0001  # Change in accuracy to be considered negligible
energy_for_each_iteration=0.01
num_of_workers=25
def energy_for_transmit(data):
    power = 1
    # energy = power * time = time = data / power = data
    return data

def terminate(accuracy, best_accuracy):
    if accuracy >= req_accuracy or abs(accuracy - best_accuracy) < negligible_change:
        return True
    return False

# %%
def local_worker_training(worker_num, global_model):
    # Shuffle the data before splitting
    workers_info[worker_num][0] = workers_info[worker_num][0].sample(frac=1, random_state=42)

    ltrain, ltest = train_test_split(workers_info[worker_num][0], test_size=0.2, random_state=42)
    lX_train = ltrain.drop('Activity', axis=1)
    ly_train = ltrain['Activity']
    lX_test = ltest.drop('Activity', axis=1)
    ly_test = ltest['Activity']

    model = DecisionTreeClassifier(random_state=42)  # Use DecisionTreeClassifier

    # Initialize variables before the if-else block
    energy_consumption_in_local = 0

    if worker_num in cluster_heads and workers_info[worker_num][2] is not None:
        energy_consumption_in_local = energy_for_transmit(sys.getsizeof(workers_info[worker_num][5]) +
                                                          sys.getsizeof(workers_info[worker_num][6]))

        # If the global model coefficients are available, set them during training
        sample_weights, _ = extract(workers_info[worker_num][2])

        if sample_weights is not None:
            sample_weights = np.ones(len(lX_train)) if sample_weights.size != len(lX_train) else sample_weights
            model.fit(lX_train, ly_train, sample_weight=sample_weights)
        else:
            model.fit(lX_train, ly_train)

        if sample_weights is not None and sample_weights.size > 1 and sample_weights.shape[0] != len(lX_train):
            sample_weights = np.repeat(sample_weights, len(lX_train) // len(sample_weights) + 1)[:len(lX_train)]

    else:
        model.fit(lX_train, ly_train)

    accuracy = model.score(lX_test, ly_test)

    energy_consumption_in_local += max_rounds * energy_for_each_iteration
    workers_info[worker_num][5].append(energy_consumption_in_local)
    workers_info[worker_num][6].append(accuracy)
    workers_info[worker_num][7] -= energy_consumption_in_local

    print("local worker:", worker_num, "acc:", accuracy, "round no:", max_rounds,
          "energy remaining:", workers_info[worker_num][7])

# %%
def training_workers(global_model=None):
    for i in range(num_of_workers):
        local_worker_training(i, global_model)

# %%
def cal_batter_life(energy_rem):
    return (energy_rem / energy_for_edge_at_start) * 100

# %%
# Modify the cal_edge_score function
def cal_edge_score():
    w1=0.4
    w2=0.6
    for i in range(num_of_workers):
        workers_info[i][3]=w1*workers_info[i][6][-1]+w2*cal_batter_life(workers_info[i][7])


# Modify the cal_clusters_head function
def cal_clusters_head():
    for i in range(5):
        max_score_edge=i*5
        for j in range(1,5):
            if workers_info[i*5+j][3]>workers_info[max_score_edge][3]:
	            max_score_edge=i*5+j
        cluster_heads[i]=max_score_edge

# %%
def global_aggregation(global_model):
    training_workers(global_model)  # Pass the global_model to training_workers
    cal_edge_score()
    cal_clusters_head()

    # Use DecisionTreeClassifier instead of RandomForestClassifier
    new_global_model = DecisionTreeClassifier(random_state=42)

    # Initialize a list to store aggregated trees
    aggregated_trees = []

    num_contributing_workers = 0

    # Initialize aggregated_tree outside the loop
    aggregated_tree = None

    for i in range(num_of_clusters):
        worker_model, _ = extract(workers_info[i][2])  # extract returns a tuple

        if worker_model:
            # Extract the tree from the worker's DecisionTreeClassifier
            tree = worker_model.tree_

            # Aggregate the tree
            if num_contributing_workers == 0:
                # If it's the first worker, simply copy the tree
                aggregated_tree = copy.deepcopy(tree)
            else:
                # Aggregate subsequent trees
                aggregated_tree.tree_ += tree.tree_

            num_contributing_workers += 1

    # Check if aggregated_tree is assigned
    if aggregated_tree is not None:
        # Normalize the aggregated tree by dividing the tree values by the number of contributing workers
        aggregated_tree.tree_ = aggregated_tree.tree_ / num_contributing_workers

        # Set the aggregated tree to the new_global_model
        new_global_model.tree_ = aggregated_tree.tree_

    return new_global_model

# %%
max_global_rounds = 15
acc = []
global_model = None  # Initialize global_model outside the loop

for i in range(max_global_rounds):
    global_model = global_aggregation(global_model)  # Pass the current global_model
    compressed_model = compress(global_model)

    temp_max_acc = 0
    for j in range(num_of_workers):
        # Ensure there are enough recorded accuracies for each worker
        if len(workers_info[j][6]) > i and workers_info[j][6][i] is not None:
            workers_info[j][2] = compressed_model
            temp_max_acc = max(temp_max_acc, workers_info[j][6][i])

            # Additional debugging information
            # print(f"local worker: {j} acc: {workers_info[j][6][i]} round no: {i} energy remaining: {workers_info[j][5]}")

    acc.append(temp_max_acc)
    print("round - global", i, "acc", temp_max_acc)
# Out:
# local worker: 0 acc: 0.8645 round no: 100 energy remaining: 99998.0
# local worker: 1 acc: 0.8618333333333333 round no: 100 energy remaining: 99998.0
# local worker: 2 acc: 0.8463333333333334 round no: 100 energy remaining: 99998.0
# local worker: 3 acc: 0.8556666666666667 round no: 100 energy remaining: 99998.0
# local worker: 4 acc: 0.8546666666666667 round no: 100 energy remaining: 99822.0
# local worker: 5 acc: 0.8486666666666667 round no: 100 energy remaining: 99822.0
# local worker: 6 acc: 0.8543333333333333 round no: 100 energy remaining: 99998.0
# local worker: 7 acc: 0.8556666666666667 round no: 100 energy remaining: 99998.0
# local worker: 8 acc: 0.8623333333333333 round no: 100 energy remaining: 99998.0
# local worker: 9 acc: 0.8521666666666666 round no: 100 energy remaining: 99998.0
# local worker: 10 acc: 0.8548333333333333 round no: 100 energy remaining: 99998.0
# local worker: 11 acc: 0.8405 round no: 100 energy remaining: 99998.0
# local worker: 12 acc: 0.8521666666666666 round no: 100 energy remaining: 99998.0
# local worker: 13 acc: 0.8421666666666666 round no: 100 energy remaining: 99998.0
# local worker: 14 acc: 0.8506666666666667 round no: 100 energy remaining: 99822.0
# local worker: 15 acc: 0.8556666666666667 round no: 100 energy remaining: 99998.0
# local worker: 16 acc: 0.8548333333333333 round no: 100 energy remaining: 99998.0
# local worker: 17 acc: 0.8481666666666666 round no: 100 energy remaining: 99998.0
# local worker: 18 acc: 0.8515 round no: 100 energy remaining: 99822.0
# local worker: 19 acc: 0.8473333333333334 round no: 100 energy remaining: 99998.0
# local worker: 20 acc: 0.8515 round no: 100 energy remaining: 99822.0
# local worker: 21 acc: 0.8455 round no: 100 energy remaining: 99998.0
# local worker: 22 acc: 0.8521666666666666 round no: 100 energy remaining: 99998.0
# local worker: 23 acc: 0.8525 round no: 100 energy remaining: 99998.0
# local worker: 24 acc: 0.8573333333333333 round no: 100 energy remaining: 99998.0
# round - global 0 acc 0.8635
# local worker: 0 acc: 0.8608333333333333 round no: 100 energy remaining: 99821.0
# local worker: 1 acc: 0.8556666666666667 round no: 100 energy remaining: 99997.0
# local worker: 2 acc: 0.8576666666666667 round no: 100 energy remaining: 99997.0
# local worker: 3 acc: 0.8521666666666666 round no: 100 energy remaining: 99997.0
# local worker: 4 acc: 0.8568333333333333 round no: 100 energy remaining: 99821.0
# local worker: 5 acc: 0.8541666666666666 round no: 100 energy remaining: 99821.0
# local worker: 6 acc: 0.8546666666666667 round no: 100 energy remaining: 99997.0
# local worker: 7 acc: 0.8566666666666667 round no: 100 energy remaining: 99997.0
# local worker: 8 acc: 0.8591666666666666 round no: 100 energy remaining: 99821.0
# local worker: 9 acc: 0.8481666666666666 round no: 100 energy remaining: 99997.0
# local worker: 10 acc: 0.8503333333333334 round no: 100 energy remaining: 99821.0
# local worker: 11 acc: 0.8443333333333334 round no: 100 energy remaining: 99997.0
# local worker: 12 acc: 0.8533333333333334 round no: 100 energy remaining: 99997.0
# local worker: 13 acc: 0.851 round no: 100 energy remaining: 99997.0
# local worker: 14 acc: 0.8466666666666667 round no: 100 energy remaining: 99821.0
# local worker: 15 acc: 0.8518333333333333 round no: 100 energy remaining: 99821.0
# local worker: 16 acc: 0.8585 round no: 100 energy remaining: 99997.0
# local worker: 17 acc: 0.8511666666666666 round no: 100 energy remaining: 99997.0
# local worker: 18 acc: 0.8565 round no: 100 energy remaining: 99821.0
# local worker: 19 acc: 0.8475 round no: 100 energy remaining: 99997.0
# local worker: 20 acc: 0.8581666666666666 round no: 100 energy remaining: 99821.0
# local worker: 21 acc: 0.8403333333333334 round no: 100 energy remaining: 99997.0
# local worker: 22 acc: 0.8566666666666667 round no: 100 energy remaining: 99997.0
# local worker: 23 acc: 0.8493333333333334 round no: 100 energy remaining: 99997.0
# local worker: 24 acc: 0.8496666666666667 round no: 100 energy remaining: 99821.0
# round - global 1 acc 0.8645
# local worker: 0 acc: 0.8566666666666667 round no: 100 energy remaining: 99820.0
# local worker: 1 acc: 0.8453333333333334 round no: 100 energy remaining: 99996.0
# local worker: 2 acc: 0.857 round no: 100 energy remaining: 99820.0
# local worker: 3 acc: 0.8533333333333334 round no: 100 energy remaining: 99996.0
# local worker: 4 acc: 0.8478333333333333 round no: 100 energy remaining: 99820.0
# local worker: 5 acc: 0.8496666666666667 round no: 100 energy remaining: 99820.0
# local worker: 6 acc: 0.8496666666666667 round no: 100 energy remaining: 99996.0
# local worker: 7 acc: 0.8571666666666666 round no: 100 energy remaining: 99820.0
# local worker: 8 acc: 0.8581666666666666 round no: 100 energy remaining: 99820.0
# local worker: 9 acc: 0.857 round no: 100 energy remaining: 99996.0
# local worker: 10 acc: 0.8601666666666666 round no: 100 energy remaining: 99820.0
# local worker: 11 acc: 0.8506666666666667 round no: 100 energy remaining: 99996.0
# local worker: 12 acc: 0.8466666666666667 round no: 100 energy remaining: 99820.0
# local worker: 13 acc: 0.8505 round no: 100 energy remaining: 99996.0
# local worker: 14 acc: 0.847 round no: 100 energy remaining: 99820.0
# local worker: 15 acc: 0.8491666666666666 round no: 100 energy remaining: 99820.0
# local worker: 16 acc: 0.8493333333333334 round no: 100 energy remaining: 99820.0
# local worker: 17 acc: 0.8571666666666666 round no: 100 energy remaining: 99996.0
# local worker: 18 acc: 0.8521666666666666 round no: 100 energy remaining: 99820.0
# local worker: 19 acc: 0.854 round no: 100 energy remaining: 99996.0
# local worker: 20 acc: 0.8446666666666667 round no: 100 energy remaining: 99820.0
# local worker: 21 acc: 0.8431666666666666 round no: 100 energy remaining: 99996.0
# local worker: 22 acc: 0.8521666666666666 round no: 100 energy remaining: 99820.0
# local worker: 23 acc: 0.8516666666666667 round no: 100 energy remaining: 99996.0
# local worker: 24 acc: 0.8508333333333333 round no: 100 energy remaining: 99820.0
# round - global 2 acc 0.8608333333333333
# local worker: 0 acc: 0.858 round no: 100 energy remaining: 99819.0
# local worker: 1 acc: 0.8498333333333333 round no: 100 energy remaining: 99995.0
# local worker: 2 acc: 0.8533333333333334 round no: 100 energy remaining: 99819.0
# local worker: 3 acc: 0.8455 round no: 100 energy remaining: 99819.0
# local worker: 4 acc: 0.8488333333333333 round no: 100 energy remaining: 99819.0
# local worker: 5 acc: 0.8558333333333333 round no: 100 energy remaining: 99819.0
# local worker: 6 acc: 0.8496666666666667 round no: 100 energy remaining: 99995.0
# local worker: 7 acc: 0.8598333333333333 round no: 100 energy remaining: 99819.0
# local worker: 8 acc: 0.8556666666666667 round no: 100 energy remaining: 99819.0
# local worker: 9 acc: 0.856 round no: 100 energy remaining: 99819.0
# local worker: 10 acc: 0.85 round no: 100 energy remaining: 99819.0
# local worker: 11 acc: 0.846 round no: 100 energy remaining: 99819.0
# local worker: 12 acc: 0.8503333333333334 round no: 100 energy remaining: 99819.0
# local worker: 13 acc: 0.853 round no: 100 energy remaining: 99995.0
# local worker: 14 acc: 0.8546666666666667 round no: 100 energy remaining: 99819.0
# local worker: 15 acc: 0.8476666666666667 round no: 100 energy remaining: 99819.0
# local worker: 16 acc: 0.8501666666666666 round no: 100 energy remaining: 99819.0
# local worker: 17 acc: 0.8471666666666666 round no: 100 energy remaining: 99819.0
# local worker: 18 acc: 0.8466666666666667 round no: 100 energy remaining: 99819.0
# local worker: 19 acc: 0.846 round no: 100 energy remaining: 99995.0
# local worker: 20 acc: 0.8583333333333333 round no: 100 energy remaining: 99819.0
# local worker: 21 acc: 0.8525 round no: 100 energy remaining: 99995.0
# local worker: 22 acc: 0.843 round no: 100 energy remaining: 99819.0
# local worker: 23 acc: 0.8596666666666667 round no: 100 energy remaining: 99819.0
# local worker: 24 acc: 0.852 round no: 100 energy remaining: 99819.0
# round - global 3 acc 0.8601666666666666
# local worker: 0 acc: 0.8465 round no: 100 energy remaining: 99818.0
# local worker: 1 acc: 0.8555 round no: 100 energy remaining: 99754.0
# local worker: 2 acc: 0.8493333333333334 round no: 100 energy remaining: 99818.0
# local worker: 3 acc: 0.8513333333333334 round no: 100 energy remaining: 99818.0
# local worker: 4 acc: 0.8551666666666666 round no: 100 energy remaining: 99818.0
# local worker: 5 acc: 0.8503333333333334 round no: 100 energy remaining: 99818.0
# local worker: 6 acc: 0.855 round no: 100 energy remaining: 99754.0
# local worker: 7 acc: 0.8498333333333333 round no: 100 energy remaining: 99818.0
# local worker: 8 acc: 0.8531666666666666 round no: 100 energy remaining: 99818.0
# local worker: 9 acc: 0.8553333333333333 round no: 100 energy remaining: 99818.0
# local worker: 10 acc: 0.8521666666666666 round no: 100 energy remaining: 99818.0
# local worker: 11 acc: 0.8518333333333333 round no: 100 energy remaining: 99818.0
# local worker: 12 acc: 0.8603333333333333 round no: 100 energy remaining: 99818.0
# local worker: 13 acc: 0.8435 round no: 100 energy remaining: 99754.0
# local worker: 14 acc: 0.8536666666666667 round no: 100 energy remaining: 99818.0
# local worker: 15 acc: 0.8541666666666666 round no: 100 energy remaining: 99818.0
# local worker: 16 acc: 0.8555 round no: 100 energy remaining: 99818.0
# local worker: 17 acc: 0.8513333333333334 round no: 100 energy remaining: 99818.0
# local worker: 18 acc: 0.8561666666666666 round no: 100 energy remaining: 99818.0
# local worker: 19 acc: 0.8556666666666667 round no: 100 energy remaining: 99754.0
# local worker: 20 acc: 0.855 round no: 100 energy remaining: 99818.0
# local worker: 21 acc: 0.8448333333333333 round no: 100 energy remaining: 99754.0
# local worker: 22 acc: 0.8428333333333333 round no: 100 energy remaining: 99818.0
# local worker: 23 acc: 0.8475 round no: 100 energy remaining: 99818.0
# local worker: 24 acc: 0.8495 round no: 100 energy remaining: 99818.0
# round - global 4 acc 0.8598333333333333
# local worker: 0 acc: 0.8558333333333333 round no: 100 energy remaining: 99817.0
# local worker: 1 acc: 0.8506666666666667 round no: 100 energy remaining: 99753.0
# local worker: 2 acc: 0.8586666666666667 round no: 100 energy remaining: 99817.0
# local worker: 3 acc: 0.8533333333333334 round no: 100 energy remaining: 99817.0
# local worker: 4 acc: 0.8556666666666667 round no: 100 energy remaining: 99577.0
# local worker: 5 acc: 0.8511666666666666 round no: 100 energy remaining: 99817.0
# local worker: 6 acc: 0.8486666666666667 round no: 100 energy remaining: 99753.0
# local worker: 7 acc: 0.8448333333333333 round no: 100 energy remaining: 99817.0
# local worker: 8 acc: 0.854 round no: 100 energy remaining: 99817.0
# local worker: 9 acc: 0.8481666666666666 round no: 100 energy remaining: 99577.0
# local worker: 10 acc: 0.8443333333333334 round no: 100 energy remaining: 99817.0
# local worker: 11 acc: 0.8491666666666666 round no: 100 energy remaining: 99817.0
# local worker: 12 acc: 0.8511666666666666 round no: 100 energy remaining: 99577.0
# local worker: 13 acc: 0.8548333333333333 round no: 100 energy remaining: 99753.0
# local worker: 14 acc: 0.856 round no: 100 energy remaining: 99817.0
# local worker: 15 acc: 0.8526666666666667 round no: 100 energy remaining: 99817.0
# local worker: 16 acc: 0.85 round no: 100 energy remaining: 99817.0
# local worker: 17 acc: 0.8503333333333334 round no: 100 energy remaining: 99817.0
# local worker: 18 acc: 0.85 round no: 100 energy remaining: 99577.0
# local worker: 19 acc: 0.8535 round no: 100 energy remaining: 99753.0
# local worker: 20 acc: 0.8533333333333334 round no: 100 energy remaining: 99577.0
# local worker: 21 acc: 0.8443333333333334 round no: 100 energy remaining: 99753.0
# local worker: 22 acc: 0.852 round no: 100 energy remaining: 99817.0
# local worker: 23 acc: 0.857 round no: 100 energy remaining: 99817.0
# local worker: 24 acc: 0.8463333333333334 round no: 100 energy remaining: 99817.0
# round - global 5 acc 0.8603333333333333
# local worker: 0 acc: 0.8545 round no: 100 energy remaining: 99816.0
# local worker: 1 acc: 0.8476666666666667 round no: 100 energy remaining: 99752.0
# local worker: 2 acc: 0.8516666666666667 round no: 100 energy remaining: 99576.0
# local worker: 3 acc: 0.8495 round no: 100 energy remaining: 99816.0
# local worker: 4 acc: 0.8476666666666667 round no: 100 energy remaining: 99576.0
# local worker: 5 acc: 0.8448333333333333 round no: 100 energy remaining: 99816.0
# local worker: 6 acc: 0.8588333333333333 round no: 100 energy remaining: 99752.0
# local worker: 7 acc: 0.8633333333333333 round no: 100 energy remaining: 99816.0
# local worker: 8 acc: 0.85 round no: 100 energy remaining: 99576.0
# local worker: 9 acc: 0.8515 round no: 100 energy remaining: 99576.0
# local worker: 10 acc: 0.8523333333333334 round no: 100 energy remaining: 99816.0
# local worker: 11 acc: 0.8538333333333333 round no: 100 energy remaining: 99816.0
# local worker: 12 acc: 0.8525 round no: 100 energy remaining: 99576.0
# local worker: 13 acc: 0.8535 round no: 100 energy remaining: 99752.0
# local worker: 14 acc: 0.8541666666666666 round no: 100 energy remaining: 99576.0
# local worker: 15 acc: 0.8525 round no: 100 energy remaining: 99576.0
# local worker: 16 acc: 0.8505 round no: 100 energy remaining: 99816.0
# local worker: 17 acc: 0.8555 round no: 100 energy remaining: 99816.0
# local worker: 18 acc: 0.8601666666666666 round no: 100 energy remaining: 99576.0
# local worker: 19 acc: 0.8408333333333333 round no: 100 energy remaining: 99752.0
# local worker: 20 acc: 0.8643333333333333 round no: 100 energy remaining: 99576.0
# local worker: 21 acc: 0.8421666666666666 round no: 100 energy remaining: 99752.0
# local worker: 22 acc: 0.8456666666666667 round no: 100 energy remaining: 99816.0
# local worker: 23 acc: 0.8548333333333333 round no: 100 energy remaining: 99576.0
# local worker: 24 acc: 0.8426666666666667 round no: 100 energy remaining: 99816.0
# round - global 6 acc 0.8586666666666667
# local worker: 0 acc: 0.8458333333333333 round no: 100 energy remaining: 99575.0
# local worker: 1 acc: 0.8588333333333333 round no: 100 energy remaining: 99751.0
# local worker: 2 acc: 0.8616666666666667 round no: 100 energy remaining: 99575.0
# local worker: 3 acc: 0.8556666666666667 round no: 100 energy remaining: 99815.0
# local worker: 4 acc: 0.8521666666666666 round no: 100 energy remaining: 99575.0
# local worker: 5 acc: 0.8413333333333334 round no: 100 energy remaining: 99815.0
# local worker: 6 acc: 0.85 round no: 100 energy remaining: 99751.0
# local worker: 7 acc: 0.8501666666666666 round no: 100 energy remaining: 99575.0
# local worker: 8 acc: 0.8583333333333333 round no: 100 energy remaining: 99575.0
# local worker: 9 acc: 0.8565 round no: 100 energy remaining: 99575.0
# local worker: 10 acc: 0.8525 round no: 100 energy remaining: 99815.0
# local worker: 11 acc: 0.8486666666666667 round no: 100 energy remaining: 99575.0
# local worker: 12 acc: 0.8555 round no: 100 energy remaining: 99575.0
# local worker: 13 acc: 0.8536666666666667 round no: 100 energy remaining: 99751.0
# local worker: 14 acc: 0.8465 round no: 100 energy remaining: 99575.0
# local worker: 15 acc: 0.845 round no: 100 energy remaining: 99575.0
# local worker: 16 acc: 0.8483333333333334 round no: 100 energy remaining: 99815.0
# local worker: 17 acc: 0.8515 round no: 100 energy remaining: 99575.0
# local worker: 18 acc: 0.8445 round no: 100 energy remaining: 99575.0
# local worker: 19 acc: 0.8571666666666666 round no: 100 energy remaining: 99751.0
# local worker: 20 acc: 0.8501666666666666 round no: 100 energy remaining: 99575.0
# local worker: 21 acc: 0.8555 round no: 100 energy remaining: 99751.0
# local worker: 22 acc: 0.849 round no: 100 energy remaining: 99575.0
# local worker: 23 acc: 0.8506666666666667 round no: 100 energy remaining: 99575.0
# local worker: 24 acc: 0.851 round no: 100 energy remaining: 99815.0
# round - global 7 acc 0.8643333333333333
# local worker: 0 acc: 0.8428333333333333 round no: 100 energy remaining: 99574.0
# local worker: 1 acc: 0.8428333333333333 round no: 100 energy remaining: 99750.0
# local worker: 2 acc: 0.8521666666666666 round no: 100 energy remaining: 99574.0
# local worker: 3 acc: 0.8501666666666666 round no: 100 energy remaining: 99446.0
# local worker: 4 acc: 0.8535 round no: 100 energy remaining: 99574.0
# local worker: 5 acc: 0.8433333333333334 round no: 100 energy remaining: 99446.0
# local worker: 6 acc: 0.8445 round no: 100 energy remaining: 99750.0
# local worker: 7 acc: 0.858 round no: 100 energy remaining: 99574.0
# local worker: 8 acc: 0.8526666666666667 round no: 100 energy remaining: 99574.0
# local worker: 9 acc: 0.8523333333333334 round no: 100 energy remaining: 99574.0
# local worker: 10 acc: 0.8525 round no: 100 energy remaining: 99446.0
# local worker: 11 acc: 0.8476666666666667 round no: 100 energy remaining: 99574.0
# local worker: 12 acc: 0.8501666666666666 round no: 100 energy remaining: 99574.0
# local worker: 13 acc: 0.8591666666666666 round no: 100 energy remaining: 99750.0
# local worker: 14 acc: 0.8436666666666667 round no: 100 energy remaining: 99574.0
# local worker: 15 acc: 0.8455 round no: 100 energy remaining: 99574.0
# local worker: 16 acc: 0.8568333333333333 round no: 100 energy remaining: 99446.0
# local worker: 17 acc: 0.8523333333333334 round no: 100 energy remaining: 99574.0
# local worker: 18 acc: 0.8491666666666666 round no: 100 energy remaining: 99574.0
# local worker: 19 acc: 0.8586666666666667 round no: 100 energy remaining: 99750.0
# local worker: 20 acc: 0.8571666666666666 round no: 100 energy remaining: 99574.0
# local worker: 21 acc: 0.8461666666666666 round no: 100 energy remaining: 99750.0
# local worker: 22 acc: 0.856 round no: 100 energy remaining: 99574.0
# local worker: 23 acc: 0.85 round no: 100 energy remaining: 99574.0
# local worker: 24 acc: 0.84 round no: 100 energy remaining: 99446.0
# round - global 8 acc 0.8616666666666667
# local worker: 0 acc: 0.8528333333333333 round no: 100 energy remaining: 99573.0
# local worker: 1 acc: 0.8515 round no: 100 energy remaining: 99381.0
# local worker: 2 acc: 0.8576666666666667 round no: 100 energy remaining: 99573.0
# local worker: 3 acc: 0.848 round no: 100 energy remaining: 99445.0
# local worker: 4 acc: 0.8563333333333333 round no: 100 energy remaining: 99573.0
# local worker: 5 acc: 0.8476666666666667 round no: 100 energy remaining: 99445.0
# local worker: 6 acc: 0.8546666666666667 round no: 100 energy remaining: 99381.0
# local worker: 7 acc: 0.8606666666666667 round no: 100 energy remaining: 99573.0
# local worker: 8 acc: 0.8566666666666667 round no: 100 energy remaining: 99573.0
# local worker: 9 acc: 0.8468333333333333 round no: 100 energy remaining: 99573.0
# local worker: 10 acc: 0.8521666666666666 round no: 100 energy remaining: 99445.0
# local worker: 11 acc: 0.8485 round no: 100 energy remaining: 99573.0
# local worker: 12 acc: 0.8468333333333333 round no: 100 energy remaining: 99573.0
# local worker: 13 acc: 0.8586666666666667 round no: 100 energy remaining: 99381.0
# local worker: 14 acc: 0.846 round no: 100 energy remaining: 99573.0
# local worker: 15 acc: 0.8513333333333334 round no: 100 energy remaining: 99573.0
# local worker: 16 acc: 0.8521666666666666 round no: 100 energy remaining: 99445.0
# local worker: 17 acc: 0.8493333333333334 round no: 100 energy remaining: 99573.0
# local worker: 18 acc: 0.857 round no: 100 energy remaining: 99573.0
# local worker: 19 acc: 0.8501666666666666 round no: 100 energy remaining: 99381.0
# local worker: 20 acc: 0.86 round no: 100 energy remaining: 99573.0
# local worker: 21 acc: 0.8433333333333334 round no: 100 energy remaining: 99381.0
# local worker: 22 acc: 0.8481666666666666 round no: 100 energy remaining: 99573.0
# local worker: 23 acc: 0.842 round no: 100 energy remaining: 99573.0
# local worker: 24 acc: 0.8548333333333333 round no: 100 energy remaining: 99445.0
# round - global 9 acc 0.8591666666666666
# local worker: 0 acc: 0.8553333333333333 round no: 100 energy remaining: 99572.0
# local worker: 1 acc: 0.8603333333333333 round no: 100 energy remaining: 99380.0
# local worker: 2 acc: 0.8506666666666667 round no: 100 energy remaining: 99204.0
# local worker: 3 acc: 0.8533333333333334 round no: 100 energy remaining: 99444.0
# local worker: 4 acc: 0.8541666666666666 round no: 100 energy remaining: 99572.0
# local worker: 5 acc: 0.8543333333333333 round no: 100 energy remaining: 99444.0
# local worker: 6 acc: 0.8551666666666666 round no: 100 energy remaining: 99380.0
# local worker: 7 acc: 0.855 round no: 100 energy remaining: 99204.0
# local worker: 8 acc: 0.8461666666666666 round no: 100 energy remaining: 99572.0
# local worker: 9 acc: 0.8523333333333334 round no: 100 energy remaining: 99572.0
# local worker: 10 acc: 0.8513333333333334 round no: 100 energy remaining: 99444.0
# local worker: 11 acc: 0.8565 round no: 100 energy remaining: 99204.0
# local worker: 12 acc: 0.8511666666666666 round no: 100 energy remaining: 99572.0
# local worker: 13 acc: 0.85 round no: 100 energy remaining: 99380.0
# local worker: 14 acc: 0.8486666666666667 round no: 100 energy remaining: 99572.0
# local worker: 15 acc: 0.8518333333333333 round no: 100 energy remaining: 99572.0
# local worker: 16 acc: 0.8591666666666666 round no: 100 energy remaining: 99444.0
# local worker: 17 acc: 0.859 round no: 100 energy remaining: 99572.0
# local worker: 18 acc: 0.8483333333333334 round no: 100 energy remaining: 99204.0
# local worker: 19 acc: 0.8553333333333333 round no: 100 energy remaining: 99380.0
# local worker: 20 acc: 0.8536666666666667 round no: 100 energy remaining: 99204.0
# local worker: 21 acc: 0.8468333333333333 round no: 100 energy remaining: 99380.0
# local worker: 22 acc: 0.855 round no: 100 energy remaining: 99572.0
# local worker: 23 acc: 0.85 round no: 100 energy remaining: 99572.0
# local worker: 24 acc: 0.8541666666666666 round no: 100 energy remaining: 99444.0
# round - global 10 acc 0.8606666666666667
# local worker: 0 acc: 0.8546666666666667 round no: 100 energy remaining: 99203.0
# local worker: 1 acc: 0.8448333333333333 round no: 100 energy remaining: 99379.0
# local worker: 2 acc: 0.85 round no: 100 energy remaining: 99203.0
# local worker: 3 acc: 0.8531666666666666 round no: 100 energy remaining: 99443.0
# local worker: 4 acc: 0.8448333333333333 round no: 100 energy remaining: 99571.0
# local worker: 5 acc: 0.8463333333333334 round no: 100 energy remaining: 99443.0
# local worker: 6 acc: 0.8521666666666666 round no: 100 energy remaining: 99379.0
# local worker: 7 acc: 0.8628333333333333 round no: 100 energy remaining: 99203.0
# local worker: 8 acc: 0.8601666666666666 round no: 100 energy remaining: 99571.0
# local worker: 9 acc: 0.8525 round no: 100 energy remaining: 99203.0
# local worker: 10 acc: 0.8645 round no: 100 energy remaining: 99443.0
# local worker: 11 acc: 0.8528333333333333 round no: 100 energy remaining: 99203.0
# local worker: 12 acc: 0.8536666666666667 round no: 100 energy remaining: 99203.0
# local worker: 13 acc: 0.8495 round no: 100 energy remaining: 99379.0
# local worker: 14 acc: 0.8561666666666666 round no: 100 energy remaining: 99571.0
# local worker: 15 acc: 0.8471666666666666 round no: 100 energy remaining: 99571.0
# local worker: 16 acc: 0.8493333333333334 round no: 100 energy remaining: 99443.0
# local worker: 17 acc: 0.8603333333333333 round no: 100 energy remaining: 99203.0
# local worker: 18 acc: 0.8561666666666666 round no: 100 energy remaining: 99203.0
# local worker: 19 acc: 0.8545 round no: 100 energy remaining: 99379.0
# local worker: 20 acc: 0.8518333333333333 round no: 100 energy remaining: 99203.0
# local worker: 21 acc: 0.8485 round no: 100 energy remaining: 99379.0
# local worker: 22 acc: 0.845 round no: 100 energy remaining: 99203.0
# local worker: 23 acc: 0.8545 round no: 100 energy remaining: 99571.0
# local worker: 24 acc: 0.853 round no: 100 energy remaining: 99443.0
# round - global 11 acc 0.8603333333333333
# local worker: 0 acc: 0.8553333333333333 round no: 100 energy remaining: 99202.0
# local worker: 1 acc: 0.8428333333333333 round no: 100 energy remaining: 99378.0
# local worker: 2 acc: 0.8521666666666666 round no: 100 energy remaining: 99202.0
# local worker: 3 acc: 0.8483333333333334 round no: 100 energy remaining: 99442.0
# local worker: 4 acc: 0.8488333333333333 round no: 100 energy remaining: 99202.0
# local worker: 5 acc: 0.8448333333333333 round no: 100 energy remaining: 99442.0
# local worker: 6 acc: 0.8503333333333334 round no: 100 energy remaining: 99378.0
# local worker: 7 acc: 0.8533333333333334 round no: 100 energy remaining: 99202.0
# local worker: 8 acc: 0.8551666666666666 round no: 100 energy remaining: 99202.0
# local worker: 9 acc: 0.8511666666666666 round no: 100 energy remaining: 99202.0
# local worker: 10 acc: 0.8655 round no: 100 energy remaining: 99442.0
# local worker: 11 acc: 0.8466666666666667 round no: 100 energy remaining: 99202.0
# local worker: 12 acc: 0.8511666666666666 round no: 100 energy remaining: 99202.0
# local worker: 13 acc: 0.8546666666666667 round no: 100 energy remaining: 99378.0
# local worker: 14 acc: 0.8396666666666667 round no: 100 energy remaining: 99202.0
# local worker: 15 acc: 0.8508333333333333 round no: 100 energy remaining: 99202.0
# local worker: 16 acc: 0.861 round no: 100 energy remaining: 99442.0
# local worker: 17 acc: 0.8536666666666667 round no: 100 energy remaining: 99202.0
# local worker: 18 acc: 0.8538333333333333 round no: 100 energy remaining: 99202.0
# local worker: 19 acc: 0.8638333333333333 round no: 100 energy remaining: 99378.0
# local worker: 20 acc: 0.8541666666666666 round no: 100 energy remaining: 99202.0
# local worker: 21 acc: 0.844 round no: 100 energy remaining: 99378.0
# local worker: 22 acc: 0.8518333333333333 round no: 100 energy remaining: 99202.0
# local worker: 23 acc: 0.8453333333333334 round no: 100 energy remaining: 99202.0
# local worker: 24 acc: 0.8451666666666666 round no: 100 energy remaining: 99442.0
# round - global 12 acc 0.8645
# local worker: 0 acc: 0.8528333333333333 round no: 100 energy remaining: 99201.0
# local worker: 1 acc: 0.8596666666666667 round no: 100 energy remaining: 99377.0
# local worker: 2 acc: 0.8485 round no: 100 energy remaining: 99201.0
# local worker: 3 acc: 0.848 round no: 100 energy remaining: 99073.0
# local worker: 4 acc: 0.8558333333333333 round no: 100 energy remaining: 99201.0
# local worker: 5 acc: 0.8528333333333333 round no: 100 energy remaining: 99073.0
# local worker: 6 acc: 0.8605 round no: 100 energy remaining: 99377.0
# local worker: 7 acc: 0.8565 round no: 100 energy remaining: 99201.0
# local worker: 8 acc: 0.8535 round no: 100 energy remaining: 99201.0
# local worker: 9 acc: 0.8555 round no: 100 energy remaining: 99201.0
# local worker: 10 acc: 0.8596666666666667 round no: 100 energy remaining: 99073.0
# local worker: 11 acc: 0.8501666666666666 round no: 100 energy remaining: 99201.0
# local worker: 12 acc: 0.8521666666666666 round no: 100 energy remaining: 99201.0
# local worker: 13 acc: 0.8598333333333333 round no: 100 energy remaining: 99377.0
# local worker: 14 acc: 0.8476666666666667 round no: 100 energy remaining: 99201.0
# local worker: 15 acc: 0.8436666666666667 round no: 100 energy remaining: 99201.0
# local worker: 16 acc: 0.8535 round no: 100 energy remaining: 99073.0
# local worker: 17 acc: 0.8601666666666666 round no: 100 energy remaining: 99201.0
# local worker: 18 acc: 0.8555 round no: 100 energy remaining: 99201.0
# local worker: 19 acc: 0.8548333333333333 round no: 100 energy remaining: 99377.0
# local worker: 20 acc: 0.8548333333333333 round no: 100 energy remaining: 99201.0
# local worker: 21 acc: 0.8511666666666666 round no: 100 energy remaining: 99377.0
# local worker: 22 acc: 0.8536666666666667 round no: 100 energy remaining: 99201.0
# local worker: 23 acc: 0.8515 round no: 100 energy remaining: 99201.0
# local worker: 24 acc: 0.84 round no: 100 energy remaining: 99073.0
# round - global 13 acc 0.8655
# local worker: 0 acc: 0.8513333333333334 round no: 100 energy remaining: 99200.0
# local worker: 1 acc: 0.8563333333333333 round no: 100 energy remaining: 99008.0
# local worker: 2 acc: 0.8548333333333333 round no: 100 energy remaining: 99200.0
# local worker: 3 acc: 0.8491666666666666 round no: 100 energy remaining: 99072.0
# local worker: 4 acc: 0.8613333333333333 round no: 100 energy remaining: 99200.0
# local worker: 5 acc: 0.8523333333333334 round no: 100 energy remaining: 99072.0
# local worker: 6 acc: 0.852 round no: 100 energy remaining: 99008.0
# local worker: 7 acc: 0.847 round no: 100 energy remaining: 99200.0
# local worker: 8 acc: 0.8566666666666667 round no: 100 energy remaining: 99200.0
# local worker: 9 acc: 0.8578333333333333 round no: 100 energy remaining: 99200.0
# local worker: 10 acc: 0.8486666666666667 round no: 100 energy remaining: 99072.0
# local worker: 11 acc: 0.847 round no: 100 energy remaining: 99200.0
# local worker: 12 acc: 0.8546666666666667 round no: 100 energy remaining: 99200.0
# local worker: 13 acc: 0.8511666666666666 round no: 100 energy remaining: 99008.0
# local worker: 14 acc: 0.8483333333333334 round no: 100 energy remaining: 99200.0
# local worker: 15 acc: 0.842 round no: 100 energy remaining: 99200.0
# local worker: 16 acc: 0.8563333333333333 round no: 100 energy remaining: 99072.0
# local worker: 17 acc: 0.8535 round no: 100 energy remaining: 99200.0
# local worker: 18 acc: 0.854 round no: 100 energy remaining: 99200.0
# local worker: 19 acc: 0.8541666666666666 round no: 100 energy remaining: 99008.0
# local worker: 20 acc: 0.8481666666666666 round no: 100 energy remaining: 99200.0
# local worker: 21 acc: 0.851 round no: 100 energy remaining: 99008.0
# local worker: 22 acc: 0.8481666666666666 round no: 100 energy remaining: 99200.0
# local worker: 23 acc: 0.8533333333333334 round no: 100 energy remaining: 99200.0
# local worker: 24 acc: 0.8523333333333334 round no: 100 energy remaining: 99072.0
# round - global 14 acc 0.8605

# %%
total_energy_per_round=[]
energy_per_round=[]
total_energy=0
for i in range(15):
    energy=0
    for j in range(num_of_workers):
        total_energy+=workers_info[j][5][i]
        energy+=workers_info[j][5][i]
    energy_per_round.append(energy)
    total_energy_per_round.append(total_energy)
energy_per_round
# Out:
# [25.0,
#  905.0,
#  905.0,
#  905.0,
#  905.0,
#  1225.0,
#  1225.0,
#  1225.0,
#  1225.0,
#  1865.0,
#  1865.0,
#  1865.0,
#  1865.0,
#  1865.0,
#  1865.0]

# %%
plt.plot(energy_per_round)
plt.xlabel("round")
plt.ylabel("energy")
plt.title("energy per round")
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming total_energy_per_round is already defined
plt.plot(total_energy_per_round, marker='o', linestyle='-', color='b')  # Customize markers, linestyle, and color
plt.xlabel("Round")
plt.ylabel("Total Energy")
plt.title("Total Energy per Round")
plt.show()

# %%
plt.plot(range(max_global_rounds), acc, marker='o')
plt.xlabel("Global Round")
plt.ylabel("Global Accuracy")
plt.title("Accuracy Over Global Rounds")
plt.show()

# %%
import numpy as np

fig, ax = plt.subplots(figsize=(10, 6))

# Calculate the total energy consumption for each worker over local rounds
total_energy_per_worker = [sum(workers_info[i][5]) for i in range(num_of_workers)]

# Plotting a bar graph
ax.bar(range(1, num_of_workers + 1), total_energy_per_worker, align='center', alpha=0.7)
ax.set_xticks(range(1, num_of_workers + 1))
ax.set_xlabel('Worker')
ax.set_ylabel('Total Energy Consumption')
ax.set_title('Total Energy Consumption for Each Worker')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming you have a list `workers_info` that contains information about each worker's energy consumption

# Calculate the average energy consumption for each global round
average_energy_consumption_per_round = np.mean([worker_info[5][:max_global_rounds] for worker_info in workers_info], axis=0)

# Plotting
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(range(1, max_global_rounds + 1), average_energy_consumption_per_round, label='Average Energy Consumption')
ax.set_xlabel('Global Round')
ax.set_ylabel('Average Energy Consumption')
ax.legend()
plt.title('Average Energy Consumption of All Workers Over Global Rounds')
plt.show()
